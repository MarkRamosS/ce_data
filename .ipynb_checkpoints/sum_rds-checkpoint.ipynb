# %%
import os 
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import json
llc_accesses = pd.read_csv('caches/llc_accesses.csv')
l1d_accesses = pd.read_csv('caches/l1d_accesses.csv')
llc_misses = pd.read_csv('caches/llc_misses.csv')
wb_accesses = pd.read_csv('caches/llc_writeback_accesses.csv')
wb_misses = pd.read_csv('caches/llc_writeback_misses.csv')

# %%
wb_accesses = wb_accesses.sort_values("id", ignore_index=True)
llc_accesses = llc_accesses.sort_values("id", ignore_index=True)
llc_misses = llc_misses.sort_values("id", ignore_index=True)
wb_misses = wb_misses.sort_values("id", ignore_index=True)
l1d_accesses = l1d_accesses.sort_values("id", ignore_index=True)
for i, j in zip(wb_accesses["id"], llc_accesses["id"]):
    if i != j: print(i)
for i, j in zip(llc_misses["id"], llc_misses["id"]):
    if i != j: print(i)

# %%
for i in ["1024", "2048", "4096", "8192"]:
    llc_accesses[i] = llc_accesses[i] - wb_accesses[i]
    llc_misses[i] = llc_misses[i] - wb_misses[i]

# %%
min_size = 512 * 1024

# out_df = pd.DataFrame()
out_df = pd.read_csv('output_512/dataset.csv')

# print(out_df)
for file in os.listdir('reuse_distances'):
    if (file[:-4]+"_0")in set(out_df["id"]):
        print(file)
        print(123)
        continue
    rd_df = pd.read_csv('reuse_distances/'+file)
    ctr1 = 0
    ctr2 = 0
    ctr4 = 0
    ctr8 = 0
    l1d_ctr1 = 0
    l1d_ctr2 = 0
    l1d_ctr4 = 0
    l1d_ctr8 = 0
    miss_ctr1 = 0
    miss_ctr2 = 0
    miss_ctr4 = 0
    miss_ctr8 = 0
    prev_ctr = 0
    for i in range(len(rd_df)):
        my_id = rd_df.iloc[i]
        row = llc_accesses[llc_accesses["id"] == my_id["id"]]
        # Accesses 
        ctr1 += int(row["1024"])
        ctr2 += int(row["2048"])
        ctr4 += int(row["4096"])
        ctr8 += int(row["8192"])
        # L1d accesses
        row = l1d_accesses[l1d_accesses["id"] == my_id["id"]]
        l1d_ctr1 += int(row["1024"])
        l1d_ctr2 += int(row["2048"])
        l1d_ctr4 += int(row["4096"])
        l1d_ctr8 += int(row["8192"])
        # Misses
        row = llc_misses[llc_misses["id"] == my_id["id"]]
        miss_ctr1 += int(row["1024"])
        miss_ctr2 += int(row["2048"])
        miss_ctr4 += int(row["4096"])
        miss_ctr8 += int(row["8192"])
        if (ctr1 > min_size) or (i == len(rd_df) - 1 and prev_ctr == 0):
            out_line = rd_df.iloc[prev_ctr: i+1].sum(axis=0)
            out_line["id"] = file[:-4] + '_' + str(prev_ctr)
            out_line = pd.DataFrame(out_line).transpose()
            out_line["accesses_1024"] = ctr1
            out_line["misses_1024"] = miss_ctr1
            out_line["accesses_2048"] = ctr2
            out_line["misses_2048"] = miss_ctr2
            out_line["accesses_4096"] = ctr4
            out_line["misses_4096"] = miss_ctr4
            out_line["accesses_8192"] = ctr8
            out_line["misses_8192"] = miss_ctr8
            out_line["l1d_accesses_1024"] = l1d_ctr1
            out_line["l1d_accesses_2048"] = l1d_ctr2
            out_line["l1d_accesses_4096"] = l1d_ctr4
            out_line["l1d_accesses_8192"] = l1d_ctr8
            out_df = pd.concat([out_df, out_line], ignore_index = True)
            prev_ctr = i+1
            ctr1 = 0
            ctr2 = 0
            ctr4 = 0
            ctr8 = 0
            l1d_ctr1 = 0
            l1d_ctr2 = 0
            l1d_ctr4 = 0
            l1d_ctr8 = 0
            miss_ctr1 = 0
            miss_ctr2 = 0
            miss_ctr4 = 0
            miss_ctr8 = 0
    print(out_df)
    out_df.to_csv('output_512/dataset.csv',index=False)
# Out:
# 400.perlbench-41B.csv
# 123
# 400.perlbench-50B.csv
# 123
# 401.bzip2-226B.csv
# 123
# 401.bzip2-277B.csv
# 123
# 401.bzip2-38B.csv
# 123
# 401.bzip2-7B.csv
# 123
# 403.gcc-16B.csv
# 123
# 403.gcc-17B.csv
# 123
# 403.gcc-48B.csv
# 123
# 410.bwaves-1963B.csv
# 123
# 410.bwaves-2097B.csv
# 123
# 410.bwaves-945B.csv
# 123
# 416.gamess-875B.csv
# 123
# 429.mcf-184B.csv
# 123
# 429.mcf-192B.csv
# 123
# 429.mcf-217B.csv
# 123
# 429.mcf-22B.csv
# 123
# 429.mcf-51B.csv
# 123
# 433.milc-127B.csv
# 123
# 433.milc-274B.csv
# 123
# 433.milc-337B.csv
# 123
# 434.zeusmp-10B.csv
# 123
# 435.gromacs-111B.csv
# 123
# 435.gromacs-134B.csv
# 123
# 435.gromacs-226B.csv
# 123
# 435.gromacs-228B.csv
# 123
# 436.cactusADM-1804B.csv
# 123
# 437.leslie3d-134B.csv
# 123
# 437.leslie3d-149B.csv
# 123
# 437.leslie3d-232B.csv
# 123
# 437.leslie3d-265B.csv
# 123
# 437.leslie3d-271B.csv
# 123
# 437.leslie3d-273B.csv
# 123
# 444.namd-120B.csv
# 123
# 444.namd-166B.csv
# 123
# 444.namd-23B.csv
# 123
# ...

# %%
dct = {}
for i in out_df["id"]:
    if i in dct:
        print("Duplicate", i)
    dct[i] = 1
