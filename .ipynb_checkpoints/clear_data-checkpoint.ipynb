# %%
import json
import os
import csv

# %%
path = 'raw_data/'
hist = {}
second_hist = {}
id_ctr = 0
fnames = []
for file in os.listdir(path):
    if file[-9:] != '_2048.out':
        continue
    hist_list = []
    with open(path+file) as f:
        lines = f.readlines()
        ctr = 0
        conf_values = ['id']
        while lines[ctr] != "~~~~~~~~~~Reuse Distance Profiler output~~~~~~~~~~\n":
            ctr += 1
        ctr += 1
        while lines[ctr] != "~~~~~~~~~~Reuse Distance Profiler output end~~~~~~~~~~\n":
            x, y, z = lines[ctr].split()
            conf_values.append(x)
            second_hist[x] = int(y)
            ctr += 1
        while len(lines) - 20 > ctr:
            while lines[ctr] != "~~~~~~~~~~Reuse Distance Profiler output~~~~~~~~~~\n":
                ctr += 1
            hist['id'] = id_ctr
            id_ctr += 1
            ctr += 1
            while lines[ctr] != "~~~~~~~~~~Reuse Distance Profiler output end~~~~~~~~~~\n":
                x, y, z = lines[ctr].split()
                hist[x] = int(y) - second_hist[x]
                second_hist[x] = int(y)
                ctr += 1
            hist_list.append(hist.copy())
    id_ctr -= 1       # Since we don't keep the last one
    fnames.append(file[:-9])
    print(f'Printing: '+'reuse_distances/'+file[:-9]+'.csv'+f', {len(hist_list)} rds')
    with open('reuse_distances/'+file[:-9]+'.csv', 'w', newline="") as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=conf_values)
        writer.writeheader()
        # writer.writerow(second_hist)    # Final/full histogram
        for hst in hist_list[:-1]:     # (last one's all 0 and first one has warmup instructions)
            writer.writerow(hst)        # In between histograms
# Out:
# Printing: reuse_distances/400.perlbench-41B.csv, 750 rds
# Printing: reuse_distances/400.perlbench-50B.csv, 750 rds
# Printing: reuse_distances/401.bzip2-226B.csv, 750 rds
# Printing: reuse_distances/401.bzip2-277B.csv, 750 rds
# Printing: reuse_distances/401.bzip2-38B.csv, 750 rds
# Printing: reuse_distances/401.bzip2-7B.csv, 750 rds
# Printing: reuse_distances/403.gcc-16B.csv, 750 rds
# Printing: reuse_distances/403.gcc-17B.csv, 750 rds
# Printing: reuse_distances/403.gcc-48B.csv, 750 rds
# Printing: reuse_distances/410.bwaves-1963B.csv, 750 rds
# Printing: reuse_distances/410.bwaves-2097B.csv, 750 rds
# Printing: reuse_distances/410.bwaves-945B.csv, 750 rds
# Printing: reuse_distances/416.gamess-875B.csv, 750 rds
# Printing: reuse_distances/429.mcf-184B.csv, 750 rds
# Printing: reuse_distances/429.mcf-192B.csv, 750 rds
# Printing: reuse_distances/429.mcf-217B.csv, 750 rds
# Printing: reuse_distances/429.mcf-22B.csv, 750 rds
# Printing: reuse_distances/429.mcf-51B.csv, 750 rds
# Printing: reuse_distances/433.milc-127B.csv, 750 rds
# Printing: reuse_distances/433.milc-274B.csv, 750 rds
# Printing: reuse_distances/433.milc-337B.csv, 750 rds
# Printing: reuse_distances/434.zeusmp-10B.csv, 750 rds
# Printing: reuse_distances/435.gromacs-111B.csv, 750 rds
# Printing: reuse_distances/435.gromacs-134B.csv, 750 rds
# Printing: reuse_distances/435.gromacs-226B.csv, 750 rds
# Printing: reuse_distances/435.gromacs-228B.csv, 750 rds
# Printing: reuse_distances/436.cactusADM-1804B.csv, 750 rds
# Printing: reuse_distances/437.leslie3d-134B.csv, 750 rds
# Printing: reuse_distances/437.leslie3d-149B.csv, 750 rds
# Printing: reuse_distances/437.leslie3d-232B.csv, 750 rds
# Printing: reuse_distances/437.leslie3d-265B.csv, 750 rds
# Printing: reuse_distances/437.leslie3d-271B.csv, 750 rds
# Printing: reuse_distances/437.leslie3d-273B.csv, 750 rds
# Printing: reuse_distances/444.namd-120B.csv, 750 rds
# Printing: reuse_distances/444.namd-166B.csv, 750 rds
# Printing: reuse_distances/444.namd-23B.csv, 750 rds
# Printing: reuse_distances/444.namd-321B.csv, 750 rds
# Printing: reuse_distances/444.namd-33B.csv, 750 rds
# Printing: reuse_distances/444.namd-426B.csv, 750 rds
# Printing: reuse_distances/444.namd-44B.csv, 750 rds
# Printing: reuse_distances/445.gobmk-17B.csv, 750 rds
# Printing: reuse_distances/445.gobmk-2B.csv, 750 rds
# Printing: reuse_distances/445.gobmk-30B.csv, 750 rds
# Printing: reuse_distances/445.gobmk-36B.csv, 750 rds
# Printing: reuse_distances/447.dealII-3B.csv, 750 rds
# Printing: reuse_distances/450.soplex-247B.csv, 750 rds
# Printing: reuse_distances/450.soplex-92B.csv, 750 rds
# Printing: reuse_distances/453.povray-252B.csv, 750 rds
# Printing: reuse_distances/453.povray-576B.csv, 750 rds
# Printing: reuse_distances/453.povray-800B.csv, 750 rds
# Printing: reuse_distances/453.povray-887B.csv, 750 rds
# Printing: reuse_distances/454.calculix-104B.csv, 750 rds
# Printing: reuse_distances/454.calculix-460B.csv, 750 rds
# Printing: reuse_distances/456.hmmer-191B.csv, 750 rds
# Printing: reuse_distances/456.hmmer-327B.csv, 750 rds
# Printing: reuse_distances/456.hmmer-88B.csv, 750 rds
# Printing: reuse_distances/458.sjeng-1088B.csv, 750 rds
# Printing: reuse_distances/458.sjeng-283B.csv, 750 rds
# Printing: reuse_distances/458.sjeng-31B.csv, 750 rds
# Printing: reuse_distances/458.sjeng-767B.csv, 750 rds
# Printing: reuse_distances/459.GemsFDTD-1169B.csv, 750 rds
# Printing: reuse_distances/459.GemsFDTD-1211B.csv, 750 rds
# Printing: reuse_distances/459.GemsFDTD-1320B.csv, 750 rds
# Printing: reuse_distances/459.GemsFDTD-1418B.csv, 750 rds
# Printing: reuse_distances/459.GemsFDTD-1491B.csv, 750 rds
# Printing: reuse_distances/459.GemsFDTD-765B.csv, 750 rds
# Printing: reuse_distances/462.libquantum-1343B.csv, 750 rds
# Printing: reuse_distances/462.libquantum-714B.csv, 750 rds
# Printing: reuse_distances/464.h264ref-30B.csv, 750 rds
# Printing: reuse_distances/464.h264ref-57B.csv, 750 rds
# Printing: reuse_distances/464.h264ref-64B.csv, 750 rds
# Printing: reuse_distances/464.h264ref-97B.csv, 750 rds
# Printing: reuse_distances/465.tonto-1914B.csv, 750 rds
# Printing: reuse_distances/465.tonto-44B.csv, 750 rds
# Printing: reuse_distances/470.lbm-1274B.csv, 750 rds
# Printing: reuse_distances/471.omnetpp-188B.csv, 750 rds
# Printing: reuse_distances/473.astar-153B.csv, 750 rds
# Printing: reuse_distances/473.astar-359B.csv, 750 rds
# Printing: reuse_distances/473.astar-42B.csv, 750 rds
# Printing: reuse_distances/481.wrf-1170B.csv, 750 rds
# Printing: reuse_distances/481.wrf-1254B.csv, 750 rds
# Printing: reuse_distances/481.wrf-1281B.csv, 750 rds
# Printing: reuse_distances/481.wrf-196B.csv, 750 rds
# Printing: reuse_distances/481.wrf-455B.csv, 750 rds
# Printing: reuse_distances/481.wrf-816B.csv, 750 rds
# Printing: reuse_distances/482.sphinx3-1100B.csv, 750 rds
# Printing: reuse_distances/482.sphinx3-1297B.csv, 750 rds
# Printing: reuse_distances/482.sphinx3-1395B.csv, 750 rds
# Printing: reuse_distances/482.sphinx3-1522B.csv, 750 rds
# Printing: reuse_distances/482.sphinx3-234B.csv, 750 rds
# Printing: reuse_distances/482.sphinx3-417B.csv, 750 rds
# Printing: reuse_distances/483.xalancbmk-127B.csv, 750 rds
# Printing: reuse_distances/483.xalancbmk-716B.csv, 750 rds
# Printing: reuse_distances/483.xalancbmk-736B.csv, 750 rds
# Printing: reuse_distances/600.perlbench_s-1273B.csv, 750 rds
# Printing: reuse_distances/600.perlbench_s-210B.csv, 750 rds
# Printing: reuse_distances/600.perlbench_s-570B.csv, 750 rds
# Printing: reuse_distances/602.gcc_s-1850B.csv, 750 rds
# Printing: reuse_distances/602.gcc_s-2226B.csv, 750 rds
# Printing: reuse_distances/602.gcc_s-2375B.csv, 750 rds
# Printing: reuse_distances/602.gcc_s-734B.csv, 750 rds
# Printing: reuse_distances/603.bwaves_s-1080B.csv, 750 rds
# Printing: reuse_distances/603.bwaves_s-1740B.csv, 750 rds
# Printing: reuse_distances/603.bwaves_s-2609B.csv, 750 rds
# Printing: reuse_distances/603.bwaves_s-2931B.csv, 750 rds
# Printing: reuse_distances/603.bwaves_s-3699B.csv, 750 rds
# Printing: reuse_distances/603.bwaves_s-5359B.csv, 750 rds
# Printing: reuse_distances/603.bwaves_s-891B.csv, 750 rds
# Printing: reuse_distances/605.mcf_s-1152B.csv, 750 rds
# Printing: reuse_distances/605.mcf_s-1536B.csv, 750 rds
# Printing: reuse_distances/605.mcf_s-1554B.csv, 750 rds
# Printing: reuse_distances/605.mcf_s-1644B.csv, 750 rds
# Printing: reuse_distances/605.mcf_s-472B.csv, 750 rds
# Printing: reuse_distances/605.mcf_s-484B.csv, 750 rds
# Printing: reuse_distances/605.mcf_s-665B.csv, 750 rds
# Printing: reuse_distances/605.mcf_s-782B.csv, 750 rds
# Printing: reuse_distances/605.mcf_s-994B.csv, 750 rds
# Printing: reuse_distances/607.cactuBSSN_s-2421B.csv, 750 rds
# Printing: reuse_distances/607.cactuBSSN_s-3477B.csv, 750 rds
# Printing: reuse_distances/607.cactuBSSN_s-4004B.csv, 750 rds
# Printing: reuse_distances/607.cactuBSSN_s-4248B.csv, 750 rds
# Printing: reuse_distances/619.lbm_s-2676B.csv, 750 rds
# Printing: reuse_distances/619.lbm_s-2677B.csv, 750 rds
# Printing: reuse_distances/619.lbm_s-3766B.csv, 750 rds
# Printing: reuse_distances/619.lbm_s-4268B.csv, 750 rds
# Printing: reuse_distances/620.omnetpp_s-141B.csv, 750 rds
# Printing: reuse_distances/620.omnetpp_s-874B.csv, 750 rds
# Printing: reuse_distances/621.wrf_s-575B.csv, 750 rds
# Printing: reuse_distances/621.wrf_s-6673B.csv, 750 rds
# Printing: reuse_distances/621.wrf_s-8065B.csv, 750 rds
# Printing: reuse_distances/621.wrf_s-8100B.csv, 750 rds
# Printing: reuse_distances/623.xalancbmk_s-10B.csv, 750 rds
# Printing: reuse_distances/623.xalancbmk_s-165B.csv, 750 rds
# Printing: reuse_distances/623.xalancbmk_s-202B.csv, 750 rds
# Printing: reuse_distances/623.xalancbmk_s-325B.csv, 750 rds
# Printing: reuse_distances/623.xalancbmk_s-592B.csv, 750 rds
# Printing: reuse_distances/623.xalancbmk_s-700B.csv, 750 rds
# Printing: reuse_distances/625.x264_s-12B.csv, 750 rds
# Printing: reuse_distances/625.x264_s-18B.csv, 750 rds
# Printing: reuse_distances/625.x264_s-20B.csv, 750 rds
# Printing: reuse_distances/625.x264_s-33B.csv, 750 rds
# Printing: reuse_distances/625.x264_s-39B.csv, 750 rds
# Printing: reuse_distances/627.cam4_s-490B.csv, 750 rds
# Printing: reuse_distances/627.cam4_s-573B.csv, 750 rds
# Printing: reuse_distances/628.pop2_s-17B.csv, 750 rds
# Printing: reuse_distances/631.deepsjeng_s-928B.csv, 750 rds
# Printing: reuse_distances/638.imagick_s-10316B.csv, 750 rds
# Printing: reuse_distances/638.imagick_s-4128B.csv, 750 rds
# Printing: reuse_distances/638.imagick_s-824B.csv, 750 rds
# Printing: reuse_distances/641.leela_s-1052B.csv, 750 rds
# Printing: reuse_distances/641.leela_s-1083B.csv, 750 rds
# Printing: reuse_distances/641.leela_s-149B.csv, 750 rds
# Printing: reuse_distances/641.leela_s-334B.csv, 750 rds
# Printing: reuse_distances/641.leela_s-602B.csv, 750 rds
# Printing: reuse_distances/641.leela_s-800B.csv, 750 rds
# Printing: reuse_distances/641.leela_s-862B.csv, 750 rds
# Printing: reuse_distances/644.nab_s-12459B.csv, 750 rds
# Printing: reuse_distances/644.nab_s-12521B.csv, 750 rds
# Printing: reuse_distances/644.nab_s-5853B.csv, 750 rds
# Printing: reuse_distances/644.nab_s-7928B.csv, 750 rds
# Printing: reuse_distances/644.nab_s-9322B.csv, 750 rds
# Printing: reuse_distances/648.exchange2_s-1227B.csv, 750 rds
# Printing: reuse_distances/648.exchange2_s-1247B.csv, 750 rds
# Printing: reuse_distances/648.exchange2_s-1511B.csv, 750 rds
# Printing: reuse_distances/648.exchange2_s-1699B.csv, 750 rds
# Printing: reuse_distances/648.exchange2_s-1712B.csv, 750 rds
# Printing: reuse_distances/648.exchange2_s-210B.csv, 750 rds
# Printing: reuse_distances/648.exchange2_s-353B.csv, 750 rds
# Printing: reuse_distances/648.exchange2_s-387B.csv, 750 rds
# Printing: reuse_distances/648.exchange2_s-584B.csv, 750 rds
# Printing: reuse_distances/648.exchange2_s-72B.csv, 750 rds
# Printing: reuse_distances/649.fotonik3d_s-10881B.csv, 750 rds
# Printing: reuse_distances/649.fotonik3d_s-1176B.csv, 750 rds
# Printing: reuse_distances/649.fotonik3d_s-1B.csv, 750 rds
# Printing: reuse_distances/649.fotonik3d_s-7084B.csv, 750 rds
# Printing: reuse_distances/649.fotonik3d_s-8225B.csv, 750 rds
# Printing: reuse_distances/654.roms_s-1007B.csv, 750 rds
# Printing: reuse_distances/654.roms_s-1021B.csv, 750 rds
# Printing: reuse_distances/654.roms_s-1070B.csv, 750 rds
# Printing: reuse_distances/654.roms_s-1390B.csv, 750 rds
# Printing: reuse_distances/654.roms_s-1613B.csv, 750 rds
# Printing: reuse_distances/654.roms_s-293B.csv, 750 rds
# Printing: reuse_distances/654.roms_s-294B.csv, 750 rds
# Printing: reuse_distances/654.roms_s-523B.csv, 750 rds
# Printing: reuse_distances/654.roms_s-842B.csv, 750 rds
# Printing: reuse_distances/657.xz_s-2302B.csv, 750 rds
# Printing: reuse_distances/657.xz_s-3167B.csv, 750 rds
# Printing: reuse_distances/657.xz_s-4994B.csv, 750 rds
# Printing: reuse_distances/657.xz_s-56B.csv, 750 rds

# %%
import pandas as pd
import numpy as np

# %%
path = 'raw_data/'
id_ctr = 0
columns = ['32','64','128','256','512','1024','2048','4096','8192']
l1d_full = pd.DataFrame()
l2c_full = pd.DataFrame()
llc_full = pd.DataFrame()
l1d_accesses_full = pd.DataFrame()
l2c_accesses_full = pd.DataFrame()
llc_accesses_full = pd.DataFrame()
l1d_misses_full = pd.DataFrame()
l2c_misses_full = pd.DataFrame()
llc_misses_full = pd.DataFrame()
for file in fnames:
    l1d_small = pd.DataFrame(0., index=np.arange(749), columns=columns)
    l2c_small = pd.DataFrame(0., index=np.arange(749), columns=columns)
    llc_small = pd.DataFrame(0., index=np.arange(749), columns=columns)
    l1d_accesses = pd.DataFrame(0, index=np.arange(749), columns=columns)
    l2c_accesses = pd.DataFrame(0, index=np.arange(749), columns=columns)
    llc_accesses = pd.DataFrame(0, index=np.arange(749), columns=columns)
    l1d_misses = pd.DataFrame(0, index=np.arange(749), columns=columns)
    l2c_misses = pd.DataFrame(0, index=np.arange(749), columns=columns)
    llc_misses = pd.DataFrame(0, index=np.arange(749), columns=columns)
    # print(file)
    for c in columns:
        fname = file + '_' + c + '.out'
        checker = False
        with open(path+fname) as f:
            lines = f.readlines()
            ctr = 0
            prev_misses_l1d = 0.
            prev_accesses_l1d = 0.
            prev_misses_l2c = 0.
            prev_accesses_l2c = 0.
            prev_misses_llc = 0.
            prev_accesses_llc = 0.
            for line in lines:
                if line != "~~~~~~~~~~Reuse Distance Profiler output~~~~~~~~~~\n":
                    checker=True
                if line[:14] == "cpu0_L1D TOTAL":
                    ctr+=1
                    if ctr == 1:
                        prev_misses_l1d = int(line.split()[7])
                        prev_accesses_l1d = int(line.split()[3])
                    if 751 > ctr > 1:
                        l1d_misses[c][ctr-2] = int(line.split()[7]) - prev_misses_l1d
                        prev_misses_l1d = int(line.split()[7])
                        l1d_accesses[c][ctr-2] = int(line.split()[3]) - prev_accesses_l1d
                        prev_accesses_l1d = int(line.split()[3])
                        if l1d_accesses[c][ctr-2] == 0: continue
                        l1d_small[c][ctr-2] = float(l1d_misses[c][ctr-2])/float(l1d_accesses[c][ctr-2])
                if line[:14] == "cpu0_L2C TOTAL":
                    if ctr == 1:
                        prev_misses_l2c = int(line.split()[7])
                        prev_accesses_l2c = int(line.split()[3])
                    if 751 > ctr > 1:
                        l2c_misses[c][ctr-2] = int(line.split()[7]) - prev_misses_l2c
                        prev_misses_l2c = int(line.split()[7])
                        l2c_accesses[c][ctr-2] = int(line.split()[3]) - prev_accesses_l2c
                        prev_accesses_l2c = int(line.split()[3])
                        if l2c_accesses[c][ctr-2] == 0: continue
                        l2c_small[c][ctr-2] = float(l2c_misses[c][ctr-2])/float(l2c_accesses[c][ctr-2])
                if line[:9] == "LLC TOTAL":
                    if ctr == 1:
                        prev_misses_llc = int(line.split()[7])
                        prev_accesses_llc = int(line.split()[3])
                    if 751 > ctr > 1:
                        llc_misses[c][ctr-2] = int(line.split()[7]) - prev_misses_llc
                        prev_misses_llc = int(line.split()[7])
                        llc_accesses[c][ctr-2] = int(line.split()[3]) - prev_accesses_llc
                        prev_accesses_llc = int(line.split()[3])
                        if llc_accesses[c][ctr-2] == 0: continue
                        llc_small[c][ctr-2] = float(llc_misses[c][ctr-2])/float(llc_accesses[c][ctr-2])
            if not checker or ctr != 751:
                print("\n Error:", fname) # Check if a file didn't finish correctly
    print("|",end="")
    l1d_full = l1d_full.append(l1d_small, ignore_index = True)
    l2c_full = l2c_full.append(l2c_small, ignore_index = True)
    llc_full = llc_full.append(llc_small, ignore_index = True)
    #print(file)
    #print(l2c_misses)
    #for c in columns:
    #    print(l2c_misses[c].sum(), end=", ")
    l1d_accesses_full = l1d_accesses_full.append(l1d_accesses, ignore_index = True)
    l2c_accesses_full = l2c_accesses_full.append(l2c_accesses, ignore_index = True)
    llc_accesses_full = llc_accesses_full.append(llc_accesses, ignore_index = True)
    l1d_misses_full = l1d_misses_full.append(l1d_misses, ignore_index = True)
    l2c_misses_full = l2c_misses_full.append(l2c_misses, ignore_index = True)
    llc_misses_full = llc_misses_full.append(llc_misses, ignore_index = True)
# Out:
# |||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#  Error: 603.bwaves_s-891B_512.out
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||

# %%
print(l2c_accesses_full)
# Out:
#           32    64   128   256   512  1024  2048  4096  8192
# 0        994   994   994   994   994   994   994   994   994
# 1       1262  1262  1262  1262  1262  1262  1262  1262  1262
# 2        761   761   761   761   761   761   761   761   761
# 3        464   464   464   464   464   464   464   464   464
# 4        831   831   831   831   831   831   831   831   831
# ...      ...   ...   ...   ...   ...   ...   ...   ...   ...
# 141556   838   838   838   838   838   838   838   838   838
# 141557   836   836   836   836   836   836   836   836   836
# 141558   838   838   838   838   838   838   838   838   838
# 141559   836   836   836   836   836   836   836   836   836
# 141560   836   836   836   836   836   836   836   836   836
#
# [141561 rows x 9 columns]

# %%
l1d_full['id'] = l1d_full.index
l2c_full['id'] = l2c_full.index
llc_full['id'] = llc_full.index
l1d_accesses_full['id'] = l1d_accesses_full.index
l2c_accesses_full['id'] = l2c_accesses_full.index
llc_accesses_full['id'] = llc_accesses_full.index
l1d_misses_full['id'] = l1d_misses_full.index
l2c_misses_full['id'] = l2c_misses_full.index
llc_misses_full['id'] = llc_misses_full.index

# %%
print(l1d_accesses_full)
print(llc_full)
# Out:
#             32      64     128     256     512    1024    2048    4096  \
# 0       506969  506971  506970  506970  506969  506967  506968  506966
# 1       482431  482431  482430  482431  482431  482431  482433  482432
# 2       484623  484623  484622  484622  484624  484623  484622  484622
# 3       479864  479864  479864  479864  479865  479864  479865  479864
# 4       512599  512598  512598  512600  512599  512598  512599  512599
# ...        ...     ...     ...     ...     ...     ...     ...     ...
# 141556  148212  148212  148212  148212  148212  148212  148212  148212
# 141557  148175  148175  148175  148175  148175  148175  148175  148175
# 141558  148188  148188  148188  148188  148188  148188  148188  148188
# 141559  148189  148189  148189  148189  148189  148189  148189  148189
# 141560  148152  148152  148152  148152  148152  148152  148152  148152
#
#           8192      id
# 0       506966       0
# 1       482432       1
# 2       484622       2
# 3       479864       3
# 4       512599       4
# ...        ...     ...
# 141556  148212  141556
# 141557  148175  141557
# 141558  148188  141558
# 141559  148189  141559
# 141560  148152  141560
#
# [141561 rows x 10 columns]
#          32   64  128       256       512      1024      2048      4096  \
# 0       1.0  1.0  1.0  0.998652  0.889488  0.828841  0.803235  0.773585
# 1       1.0  1.0  1.0  1.000000  0.928650  0.875960  0.849616  0.839737
# 2       1.0  1.0  1.0  1.000000  0.950963  0.872154  0.856392  0.845884
# 3       1.0  1.0  1.0  1.000000  0.946746  0.866864  0.857988  0.840237
# 4       1.0  1.0  1.0  1.000000  0.956240  0.878444  0.858995  0.849271
# ...     ...  ...  ...       ...       ...       ...       ...       ...
# 141556  1.0  1.0  1.0  1.000000  1.000000  1.000000  1.000000  1.000000
# 141557  1.0  1.0  1.0  1.000000  1.000000  1.000000  1.000000  1.000000
# 141558  1.0  1.0  1.0  1.000000  1.000000  1.000000  1.000000  1.000000
# 141559  1.0  1.0  1.0  1.000000  1.000000  1.000000  1.000000  1.000000
# 141560  1.0  1.0  1.0  1.000000  1.000000  1.000000  1.000000  1.000000
#
#             8192      id
# 0       0.768194       0
# 1       0.837541       1
# 2       0.844133       2
# 3       0.837278       3
# 4       0.849271       4
# ...          ...     ...
# 141556  1.000000  141556
# 141557  1.000000  141557
# 141558  1.000000  141558
# 141559  1.000000  141559
# 141560  1.000000  141560
#
# [141561 rows x 10 columns]

# %%
l1d_full.to_csv('caches/l1d_miss_ratio.csv')
l2c_full.to_csv('caches/l2c_miss_ratio.csv')
llc_full.to_csv('caches/llc_miss_ratio.csv')
l1d_accesses_full.to_csv('caches/l1d_accesses.csv')
l2c_accesses_full.to_csv('caches/l2c_accesses.csv')
llc_accesses_full.to_csv('caches/llc_accesses.csv')
l1d_misses_full.to_csv('caches/l1d_misses.csv')
l2c_misses_full.to_csv('caches/l2c_misses.csv')
llc_misses_full.to_csv('caches/llc_misses.csv')
